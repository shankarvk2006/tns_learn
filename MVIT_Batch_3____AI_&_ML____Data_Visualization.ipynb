# %% [markdown]
# <a href="https://colab.research.google.com/github/shankarvk2006/tns_learn/blob/main/MVIT_Batch_3____AI_%26_ML____Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib, Seaborn & Plotly — Data Visualization
#
# Data visualization transforms raw numbers into intuitive visual insights.
#
# * **Matplotlib:** Low-level, highly customizable library for basic plotting.
# * **Seaborn:** High-level statistical visualization library built on top of Matplotlib with stylish defaults.
# * **Plotly:** Interactive charting library ideal for web apps and dynamic dashboards.
#
# ---
#
# ### Core Visualization Reference:
#
# | Library | Function / Plot | Usage |
# | :--- | :--- | :--- |
# | **Matplotlib** | `plt.plot()` | Line Plot (trends over time) |
# | | `plt.bar()` | Bar Plot (comparing categories) |
# | | `plt.scatter()` | Scatter Plot (relationship between two variables) |
# | **Seaborn** | `sns.heatmap()` | Matrix heatmaps (correlations, confusion matrices) |
# | | `sns.pairplot()` | Grid of scatter plots for all numerical variables |
# | **Plotly** | `px.scatter()` / `px.bar()` | Interactive plots with tooltips, zoom, and pan |
#
# ---

# %%
import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [10, 24, 36, 40, 52]
categories = ["A", "B", "C", "D", "E"]
values = [15, 30, 45, 10, 25]

# %%
# Line Plot
plt.figure(figsize=(5, 3))
plt.plot(x, y, marker="o", color="b", linestyle="--")
plt.title("Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %%
# Bar Plot
plt.figure(figsize=(5, 3))
plt.bar(categories, values, color="skyblue")
plt.title("Bar Plot Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(5, 3))
plt.scatter(x, y, color="red", s=100)  # s controls point size
plt.title("Scatter Plot Example")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %% [markdown]
# 2. Advanced Visualization with Seaborn (Heatmaps, Pair Plots)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Create a simple Student dataset
data = {
    "Hours_Studied": [2, 5, 7, 8, 10],
    "Attendance_%": [60, 75, 80, 90, 95],
    "Exam_Score": [50, 65, 78, 88, 98]
}
df = pd.DataFrame(data)

# --- HEATMAP EXAMPLE ---
# Calculate correlation (how numbers relate to each other)
matrix = df.corr()

# Draw the heatmap (annot=True displays the actual numbers)
plt.figure(figsize=(5, 4))
sns.heatmap(matrix, annot=True, cmap="YlGnBu")
plt.title("Study Habits vs Score Correlation")
plt.show()

# --- PAIR PLOT EXAMPLE ---
# Automatically plots every variable against each other
sns.pairplot(df)
plt.show()

# %% [markdown]
# 3. Interactive Plots with Plotly

# %%
import plotly.express as px
import pandas as pd

# Step 1: Create a simple dataset of students in different cities
data = {
    "Student_Name": ["Divya", "Arjun", "Eshwar", "Kavya", "Rahul"],
    "City": ["Chennai", "Bangalore", "Chennai", "Hyderabad", "Bangalore"],
    "Marks": [85, 92, 78, 88, 95],
    "Attendance": [90, 95, 80, 85, 98]
}
df = pd.DataFrame(data)

# --- INTERACTIVE SCATTER PLOT ---
# Hovering over a dot will reveal the student's name, marks, and attendance
fig_scatter = px.scatter(
    df,
    x="Attendance",
    y="Marks",
    color="City",
    hover_name="Student_Name",
    title="Marks vs Attendance by City (Hover over points!)"
)
fig_scatter.show()

# --- INTERACTIVE BAR CHART ---
fig_bar = px.bar(
    df,
    x="Student_Name",
    y="Marks",
    color="City",
    title="Student Marks Comparison"
)
fig_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
