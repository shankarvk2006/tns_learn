# %% [markdown]
# <a href="https://colab.research.google.com/github/shankarvk2006/tns_learn/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 24, 36, 40, 52]
categories = ["A", "B", "C", "D", "E"]
values = [15, 30, 45, 10, 25]

# %%
plt.figure(figsize=(5, 3))
plt.plot(x, y, marker="o", color="b", linestyle="--")
plt.title("Line Plot Example")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.bar(categories, values, color="skyblue")
plt.title("Bar Plot Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %%
plt.figure(figsize=(5, 3))
plt.scatter(x, y, color="red", s=100)  # s controls point size
plt.title("Scatter Plot Example")
plt.xlabel("X Values")
plt.ylabel("Y Values")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
